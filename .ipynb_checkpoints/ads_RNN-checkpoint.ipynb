# %%
# importing necessary libraries
import warnings
warnings.filterwarnings('ignore')

import random
random.seed(42)

import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %config InlineBackend.figure_format = 'retina'
import datetime
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ads_hour.csv',
                 index_col=['Date'], parse_dates=['Date'])

# %%
with plt.style.context('bmh'):    
    plt.figure(figsize=(15, 8))
    plt.title('Ads watched (hour ticks)')
    plt.plot(df.ads);

# %%
df.head()
# Out:
#                        ads
# Date
# 2017-08-03 00:00:00  49136
# 2017-08-03 01:00:00  46450
# 2017-08-03 02:00:00  46355
# 2017-08-03 03:00:00  43748
# 2017-08-03 04:00:00  42281

# %%
scaler = MinMaxScaler()
df.ads = scaler.fit_transform(df.ads.to_numpy().reshape((-1,1)))

# %%
def prepareData(data,n_steps = 50, test_size=0.20):
    """
    series: pd.DataFrame
        dataframe with timeseries

    lag_start: int
        initial step back in time to slice target variable 
        example - lag_start = 1 means that the model 
                  will see yesterday's values to predict today

    lag_end: int
        final step back in time to slice target variable
        example - lag_end = 4 means that the model 
                  will see up to 4 days back in time to predict today

    test_size: float
        size of the test dataset after train/test split as percentage of dataset

    """
    data = pd.DataFrame(data.copy())
    data.columns = ["ads"]
    
    # adding lags of original time series data as features
#     for i in range(lag_start, lag_end):
#         data["lag_{}".format(i)] = data.y.shift(i)
        
    # transforming df index to datetime and creating new variables
    data.index = pd.to_datetime(data.index)
    data["hour"] = data.index.hour
    data["weekday"] = data.index.weekday
        
    # since we will be using only linear models we need to get dummies from weekdays 
    # to avoid imposing weird algebraic rules on day numbers
    data = pd.concat([
        data.drop("weekday", axis=1), 
        pd.get_dummies(data['weekday'], prefix='weekday')
    ], axis=1)
        
    # encode hour with sin/cos transformation
    # credits - https://ianlondon.github.io/blog/encoding-cyclical-features-24hour-time/
    data['sin_hour'] = np.sin(2*np.pi*data['hour']/24)
    data['cos_hour'] = np.cos(2*np.pi*data['hour']/24)
    data.drop(["hour"], axis=1, inplace=True)
        
    
    data = data.dropna()
    data = data.reset_index(drop=True)
    size = data.shape[0]-n_steps-9
    
    serie = np.empty((size, n_steps+10, 10))
    for i in range(size):
        serie[i,:,:] = data[i:i+n_steps+10]

    X = serie[:, :n_steps]
    Y = np.empty((size, n_steps, 10))
    for step_ahead in range(1, 10 + 1):
        Y[:, :, step_ahead - 1] = serie[:, step_ahead:step_ahead + n_steps, 0]     
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size,shuffle=False ,random_state=42)
    return X_train, X_test, Y_train, Y_test

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
X_train, X_test, y_train, y_test = prepareData(df)

# %%
X_train.shape,y_train.shape
# Out:
# ((1620, 50, 10), (1620, 50, 10))

# %%
model = keras.models.Sequential([
    keras.layers.LSTM(32, return_sequences=True, input_shape=[None, 10]),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse],use_multiprocessing=True)

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_test, y_test))
# Out:
# Train on 1620 samples, validate on 406 samples
# Epoch 1/20
# 1620/1620 [==============================] - 3s 2ms/sample - loss: 0.0787 - last_time_step_mse: 0.0759 - val_loss: 0.0643 - val_last_time_step_mse: 0.0453
# Epoch 2/20
# 1620/1620 [==============================] - 0s 197us/sample - loss: 0.0137 - last_time_step_mse: 0.0083 - val_loss: 0.0478 - val_last_time_step_mse: 0.0366
# Epoch 3/20
# 1620/1620 [==============================] - 0s 197us/sample - loss: 0.0095 - last_time_step_mse: 0.0054 - val_loss: 0.0358 - val_last_time_step_mse: 0.0277
# Epoch 4/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0074 - last_time_step_mse: 0.0041 - val_loss: 0.0266 - val_last_time_step_mse: 0.0197
# Epoch 5/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0058 - last_time_step_mse: 0.0028 - val_loss: 0.0160 - val_last_time_step_mse: 0.0073
# Epoch 6/20
# 1620/1620 [==============================] - 0s 197us/sample - loss: 0.0047 - last_time_step_mse: 0.0022 - val_loss: 0.0125 - val_last_time_step_mse: 0.0046
# Epoch 7/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0040 - last_time_step_mse: 0.0019 - val_loss: 0.0104 - val_last_time_step_mse: 0.0035
# Epoch 8/20
# 1620/1620 [==============================] - 0s 191us/sample - loss: 0.0036 - last_time_step_mse: 0.0018 - val_loss: 0.0093 - val_last_time_step_mse: 0.0032
# Epoch 9/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0032 - last_time_step_mse: 0.0017 - val_loss: 0.0088 - val_last_time_step_mse: 0.0035
# Epoch 10/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0030 - last_time_step_mse: 0.0016 - val_loss: 0.0079 - val_last_time_step_mse: 0.0032
# Epoch 11/20
# 1620/1620 [==============================] - 0s 204us/sample - loss: 0.0028 - last_time_step_mse: 0.0016 - val_loss: 0.0077 - val_last_time_step_mse: 0.0036
# Epoch 12/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0026 - last_time_step_mse: 0.0016 - val_loss: 0.0068 - val_last_time_step_mse: 0.0031
# Epoch 13/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0025 - last_time_step_mse: 0.0015 - val_loss: 0.0070 - val_last_time_step_mse: 0.0037
# Epoch 14/20
# 1620/1620 [==============================] - 0s 210us/sample - loss: 0.0024 - last_time_step_mse: 0.0015 - val_loss: 0.0066 - val_last_time_step_mse: 0.0036
# Epoch 15/20
# 1620/1620 [==============================] - 0s 222us/sample - loss: 0.0023 - last_time_step_mse: 0.0015 - val_loss: 0.0063 - val_last_time_step_mse: 0.0037
# Epoch 16/20
# 1620/1620 [==============================] - 0s 210us/sample - loss: 0.0022 - last_time_step_mse: 0.0015 - val_loss: 0.0062 - val_last_time_step_mse: 0.0039
# Epoch 17/20
# 1620/1620 [==============================] - 0s 204us/sample - loss: 0.0021 - last_time_step_mse: 0.0015 - val_loss: 0.0054 - val_last_time_step_mse: 0.0033
# Epoch 18/20
# 1620/1620 [==============================] - 0s 197us/sample - loss: 0.0020 - last_time_step_mse: 0.0015 - val_loss: 0.0055 - val_last_time_step_mse: 0.0037
# Epoch 19/20
# 1620/1620 [==============================] - 0s 210us/sample - loss: 0.0020 - last_time_step_mse: 0.0015 - val_loss: 0.0054 - val_last_time_step_mse: 0.0038
# Epoch 20/20
# 1620/1620 [==============================] - 0s 198us/sample - loss: 0.0019 - last_time_step_mse: 0.0014 - val_loss: 0.0051 - val_last_time_step_mse: 0.0036

# %%
pred = model(X_test)
pred1 = np.empty((525))
pred1 = pred[:,49,0]
y1 = y_test[:,49,0]

plt.figure(figsize=(40,7))
sns.lineplot(data=pred1)
sns.lineplot(data=y1)

# %%
X= np.concatenate((X_train,X_test),axis=0)
full_pred=model.predict(X)
plt.figure(figsize=(40,7))
nb_input = 50
steps_ahead = 0
Y = np.concatenate((y_train,y_test),axis=0)
plt_Y = scaler.inverse_transform(Y[:,nb_input-1,steps_ahead-1].reshape(-1,1))
plt_pred = scaler.inverse_transform(full_pred[:,nb_input-1,steps_ahead-1])

mae  = mean_absolute_error(plt_pred, plt_Y)
mape = mean_absolute_percentage_error(plt_pred, plt_Y)

sns.lineplot(data=plt_Y)
sns.lineplot(data=plt_pred)
plt.legend(labels=['True','Prediction'])
plt.title("MAE {}, MAPE {}%".format(round(mae), round(mape, 2)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-3168306c550f> in <module>
#       6 Y = np.concatenate((y_train,y_test),axis=0)
#       7 plt_Y = scaler.inverse_transform(Y[:,nb_input-1,steps_ahead-1].reshape(-1,1))
# ----> 8 plt_pred = scaler.inverse_transform(full_pred[:,nb_input-1,steps_ahead-1])
#       9
#      10 mae  = mean_absolute_error(plt_pred, plt_Y)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\data.py in inverse_transform(self, X)
#     402
#     403         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
# --> 404                         force_all_finite="allow-nan")
#     405
#     406         X -= self.min_
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.11607615 0.13243292 0.15282127 ... 0.7174883  0.7620891  0.79884034].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
