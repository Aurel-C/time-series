# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %config InlineBackend.figure_format = 'retina'
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('ads_hour.csv', index_col=['Date'], parse_dates=['Date'])

# %%
with plt.style.context('bmh'):    
    plt.figure(figsize=(15, 8))
    plt.title('Ads watched (hour ticks)')
    plt.plot(data.ads);

# %%
scaler = StandardScaler()
data = scaler.fit_transform(data)

# %%
n_steps = 50
serie = np.empty((2025, n_steps+10, 1))
for i in range(2025):
    serie[i,:,:] = data[i:i+n_steps+10]

# %%
serie.shape
# Out:
# (2025, 60, 1)

# %%
# X_train, Y_train = serie[:1500, :n_steps], serie[:1500, -10:, 0]
# X_test, Y_test = serie[1500:, :n_steps], serie[1500:, -10:, 0]
X = serie[:, :n_steps]
Y = np.empty((2025, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[:, :, step_ahead - 1] = serie[:, step_ahead:step_ahead + n_steps, 0]
    
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25,shuffle=False ,random_state=42)

# %%
serie.shape,Y_train.shape
# Out:
# ((2025, 60, 1), (1518, 50, 10))

# %%
def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

# %%
model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

# %%
history = model.fit(X_train, Y_train, epochs=50,validation_data=(X_test, Y_test),)
# Out:
# Train on 1518 samples, validate on 507 samples
# Epoch 1/50
# 1518/1518 [==============================] - 3s 2ms/sample - loss: 0.5761 - last_time_step_mse: 0.5245 - val_loss: 1.6991 - val_last_time_step_mse: 1.8543
# Epoch 2/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.3353 - last_time_step_mse: 0.2260 - val_loss: 1.0236 - val_last_time_step_mse: 0.6834
# Epoch 3/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.2225 - last_time_step_mse: 0.1287 - val_loss: 0.6335 - val_last_time_step_mse: 0.3695
# Epoch 4/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1706 - last_time_step_mse: 0.0987 - val_loss: 0.5570 - val_last_time_step_mse: 0.3563
# Epoch 5/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.1465 - last_time_step_mse: 0.0862 - val_loss: 0.4471 - val_last_time_step_mse: 0.2743
# Epoch 6/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1350 - last_time_step_mse: 0.0802 - val_loss: 0.3943 - val_last_time_step_mse: 0.2493
# Epoch 7/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.1281 - last_time_step_mse: 0.0765 - val_loss: 0.3892 - val_last_time_step_mse: 0.2632
# Epoch 8/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.1225 - last_time_step_mse: 0.0731 - val_loss: 0.3317 - val_last_time_step_mse: 0.2035
# Epoch 9/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1186 - last_time_step_mse: 0.0705 - val_loss: 0.3321 - val_last_time_step_mse: 0.2115
# Epoch 10/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.1145 - last_time_step_mse: 0.0690 - val_loss: 0.3952 - val_last_time_step_mse: 0.2720
# Epoch 11/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1133 - last_time_step_mse: 0.0676 - val_loss: 0.3696 - val_last_time_step_mse: 0.2537
# Epoch 12/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1095 - last_time_step_mse: 0.0657 - val_loss: 0.3488 - val_last_time_step_mse: 0.2436
# Epoch 13/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.1074 - last_time_step_mse: 0.0643 - val_loss: 0.3204 - val_last_time_step_mse: 0.2067
# Epoch 14/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.1044 - last_time_step_mse: 0.0622 - val_loss: 0.3795 - val_last_time_step_mse: 0.2603
# Epoch 15/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.1024 - last_time_step_mse: 0.0605 - val_loss: 0.3376 - val_last_time_step_mse: 0.2331
# Epoch 16/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.1010 - last_time_step_mse: 0.0592 - val_loss: 0.3559 - val_last_time_step_mse: 0.2502
# Epoch 17/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.1000 - last_time_step_mse: 0.0588 - val_loss: 0.3813 - val_last_time_step_mse: 0.2801
# Epoch 18/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0989 - last_time_step_mse: 0.0580 - val_loss: 0.3907 - val_last_time_step_mse: 0.2676
# Epoch 19/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0968 - last_time_step_mse: 0.0564 - val_loss: 0.4016 - val_last_time_step_mse: 0.3093
# Epoch 20/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0957 - last_time_step_mse: 0.0559 - val_loss: 0.3325 - val_last_time_step_mse: 0.2262
# Epoch 21/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0946 - last_time_step_mse: 0.0546 - val_loss: 0.3641 - val_last_time_step_mse: 0.2616
# Epoch 22/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0944 - last_time_step_mse: 0.0548 - val_loss: 0.3529 - val_last_time_step_mse: 0.2460
# Epoch 23/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0931 - last_time_step_mse: 0.0539 - val_loss: 0.3351 - val_last_time_step_mse: 0.2398
# Epoch 24/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.0924 - last_time_step_mse: 0.0534 - val_loss: 0.3323 - val_last_time_step_mse: 0.2391
# Epoch 25/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0916 - last_time_step_mse: 0.0525 - val_loss: 0.3783 - val_last_time_step_mse: 0.2612
# Epoch 26/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0914 - last_time_step_mse: 0.0522 - val_loss: 0.3853 - val_last_time_step_mse: 0.2849
# Epoch 27/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.0898 - last_time_step_mse: 0.0505 - val_loss: 0.3830 - val_last_time_step_mse: 0.2738
# Epoch 28/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.0887 - last_time_step_mse: 0.0500 - val_loss: 0.3348 - val_last_time_step_mse: 0.2415
# Epoch 29/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0893 - last_time_step_mse: 0.0511 - val_loss: 0.3778 - val_last_time_step_mse: 0.2869
# Epoch 30/50
# 1518/1518 [==============================] - 0s 231us/sample - loss: 0.0874 - last_time_step_mse: 0.0495 - val_loss: 0.3214 - val_last_time_step_mse: 0.2133
# Epoch 31/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0873 - last_time_step_mse: 0.0489 - val_loss: 0.3320 - val_last_time_step_mse: 0.2414
# Epoch 32/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0891 - last_time_step_mse: 0.0506 - val_loss: 0.3956 - val_last_time_step_mse: 0.3022
# Epoch 33/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0863 - last_time_step_mse: 0.0484 - val_loss: 0.3737 - val_last_time_step_mse: 0.2819
# Epoch 34/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0874 - last_time_step_mse: 0.0495 - val_loss: 0.3303 - val_last_time_step_mse: 0.2401
# Epoch 35/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.0856 - last_time_step_mse: 0.0472 - val_loss: 0.3643 - val_last_time_step_mse: 0.2589
# Epoch 36/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0845 - last_time_step_mse: 0.0472 - val_loss: 0.3555 - val_last_time_step_mse: 0.2550
# Epoch 37/50
# 1518/1518 [==============================] - 0s 211us/sample - loss: 0.0836 - last_time_step_mse: 0.0455 - val_loss: 0.3566 - val_last_time_step_mse: 0.2353
# Epoch 38/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0841 - last_time_step_mse: 0.0466 - val_loss: 0.3268 - val_last_time_step_mse: 0.2145
# Epoch 39/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0824 - last_time_step_mse: 0.0446 - val_loss: 0.3938 - val_last_time_step_mse: 0.2676
# Epoch 40/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0826 - last_time_step_mse: 0.0451 - val_loss: 0.3590 - val_last_time_step_mse: 0.2426
# Epoch 41/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0813 - last_time_step_mse: 0.0444 - val_loss: 0.3601 - val_last_time_step_mse: 0.2503
# Epoch 42/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0813 - last_time_step_mse: 0.0436 - val_loss: 0.3510 - val_last_time_step_mse: 0.2476
# Epoch 43/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0809 - last_time_step_mse: 0.0429 - val_loss: 0.3256 - val_last_time_step_mse: 0.2339
# Epoch 44/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0813 - last_time_step_mse: 0.0440 - val_loss: 0.3459 - val_last_time_step_mse: 0.2443
# Epoch 45/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.0800 - last_time_step_mse: 0.0430 - val_loss: 0.3532 - val_last_time_step_mse: 0.2417
# Epoch 46/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0795 - last_time_step_mse: 0.0418 - val_loss: 0.3355 - val_last_time_step_mse: 0.2319
# Epoch 47/50
# 1518/1518 [==============================] - 0s 217us/sample - loss: 0.0786 - last_time_step_mse: 0.0411 - val_loss: 0.3514 - val_last_time_step_mse: 0.2517
# Epoch 48/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0786 - last_time_step_mse: 0.0410 - val_loss: 0.3671 - val_last_time_step_mse: 0.2572
# Epoch 49/50
# 1518/1518 [==============================] - 0s 218us/sample - loss: 0.0780 - last_time_step_mse: 0.0408 - val_loss: 0.3530 - val_last_time_step_mse: 0.2546
# Epoch 50/50
# 1518/1518 [==============================] - 0s 224us/sample - loss: 0.0768 - last_time_step_mse: 0.0395 - val_loss: 0.3954 - val_last_time_step_mse: 0.3161

# %%
pred = model(X_test)
# Out:
# WARNING:tensorflow:Layer conv1d is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
plot_y = np.empty((525, 60))
plt_pred = np.empty((525, 60))

plot_y = np.hstack((Y_test[:,:,0],Y_test[:,49,:]))
plt_pred = np.hstack((pred[:,:,0],pred[:,49,:]))

# %%
index = 475;
sns.lineplot(data=plot_y[index,:])
sns.lineplot(data=plt_pred[index,:])

# %%
pred1 = np.empty((525))
pred1 = scaler.inverse_transform(pred[:,49,0])
y1 = scaler.inverse_transform(Y_test[:,49,0])

plt.figure(figsize=(40,7))
sns.lineplot(data=pred1)
sns.lineplot(data=y1)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
mae  = mean_absolute_error(pred1, y1)
mape = mean_absolute_percentage_error(pred1, y1)
mae,mape
# Out:
# (6081.664054795365, 7.8795752099096745)

# %%
full_pred=model(X)

# %%
plt.figure(figsize=(40,7))
nb_input = 50
steps_ahead = 0
plt_Y = scaler.inverse_transform(Y[:,nb_input-1,steps_ahead-1])
plt_pred = scaler.inverse_transform(full_pred[:,nb_input-1,steps_ahead-1])

mae  = mean_absolute_error(plt_pred, plt_Y)
mape = mean_absolute_percentage_error(plt_pred, plt_Y)

sns.lineplot(data=plt_Y)
sns.lineplot(data=plt_pred)
plt.legend(labels=['True','Prediction'])
plt.title("MAE {}, MAPE {}%".format(round(mae), round(mape, 2)))
# Out:
# Text(0.5, 1.0, 'MAE 4593.0, MAPE 6.78%')

# %%
X
# Out:
# array([[[-0.96888712],
#         [-1.12038574],
#         [-1.12574403],
#         ...,
#         [-1.04717457],
#         [-1.12016013],
#         [-1.22224967]],
#
#        [[-1.12038574],
#         [-1.12574403],
#         [-1.27278681],
#         ...,
#         [-1.12016013],
#         [-1.22224967],
#         [-1.31362263]],
#
#        [[-1.12574403],
#         [-1.27278681],
#         [-1.3555301 ],
#         ...,
#         [-1.22224967],
#         [-1.31362263],
#         [-1.42975653]],
#
#        ...,
#
#        [[ 1.77218882],
#         [ 1.70444874],
#         [ 1.47426785],
#         ...,
#         [ 1.34290512],
#         [ 1.18441252],
#         [ 1.12941954]],
#
#        [[ 1.70444874],
#         [ 1.47426785],
#         [ 1.1083812 ],
#         ...,
#         [ 1.18441252],
#         [ 1.12941954],
#         [ 1.12067706]],
#
#        [[ 1.47426785],
#         [ 1.1083812 ],
#         [ 0.84328681],
#         ...,
#         [ 1.12941954],
#         [ 1.12067706],
#         [ 1.30889408]]])
